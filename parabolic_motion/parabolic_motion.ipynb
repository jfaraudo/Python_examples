# %% [markdown]
# ## Example parabolic motion

# %% [markdown]
# Example of use of numpy and Matplotlib to plot data for a problem with known analytical solution

# %%
# Here we import the mathematical library and the plots library
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# *Physical parameters of the problem: acceleration of gravity (m/s2), modulus of initial velocity (m/s) and angle (deg)*

# %%
g=9.8 #m/s2

# %%
u=20.0 #m/s

# %%
theta=45

# %%
#convert angle in degrees to rad
theta = np.radians(theta)
print(theta, "rad")
# Out:
# 0.7853981633974483 rad

# %% [markdown]
# **Solve the parabolic motion**

# %% [markdown]
# *Calculate time of flight*

# %%
t_flight = 2*u*np.sin(theta)/g

# %%
print(t_flight, "seconds")
# Out:
# 2.8861501272920305 seconds

# %% [markdown]
# *Divide the time in discrete intervals of size dt*

# %%
dt=0.001 #seconds

# %%
t = np.arange(0,t_flight,dt)
print(t)
# Out:
# [0.000e+00 1.000e-03 2.000e-03 ... 2.884e+00 2.885e+00 2.886e+00]

# %% [markdown]
# *Calculate the position x,y for each time in the interval*

# %%
x=u*np.cos(theta)*t

# %%
y=u*np.sin(theta)*t - (1.0/2.0)*g*t*t

# %%
print(x)
# Out:
# [0.00000000e+00 1.41421356e-02 2.82842712e-02 ... 4.07859191e+01
#  4.08000613e+01 4.08142034e+01]

# %%
print(y)
# Out:
# [0.         0.01413724 0.02826467 ... 0.03038474 0.01625877 0.00212301]

# %% [markdown]
# Plot the results

# %%
plt.plot(x, y)
plt.xlabel('Distance (m)')
plt.ylabel('Height (m)')
plt.title('Projectile motion')
plt.savefig("example.png")
plt.show()
