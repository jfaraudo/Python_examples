# %% [markdown]
# **A Simple Example using NumPy**

# %% [markdown]
# Let us import the numpy library

# %%
import numpy as np

# %% [markdown]
# use a numpy function

# %%
np.exp(1.0)

# %%
np.exp(-2.0)

# %% [markdown]
# Let us make a list of data

# %%
x = np.arange(0.0,2.0,0.1)
print(x)

# %% [markdown]
# and let us calculate something from the list

# %%
y=np.exp(x)
print(y)

# %% [markdown]
# Let us plot this function. First, let us import the matplotlib library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# and now let us plot it!

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# we can use different colors and symbols

# %%
plt.plot(x,y,'bo')
plt.show()

# %%
plt.plot(x,y,'bv')
plt.show()

# %%
plt.plot(x,y,'rv')
plt.show()

# %% [markdown]
# We can add another function and plot both functions together

# %%
z=np.exp(-x)

# %%
plt.plot(x,y,'ro',x,z,'bv')
plt.show()

# %% [markdown]
# We can make the figure nicer and save it to a file

# %%
plt.plot(x,y,'ro',x,z,'bv')
plt.xlabel("x")
plt.ylabel("Function")
plt.savefig("example.png")
plt.show()
